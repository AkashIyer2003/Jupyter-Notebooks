# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/akash/Downloads/annual-enterprise-survey-2021-financial-year-provisional-csv.csv")

# %%
df.head(10)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
# 5  2021                     Level 1                99999       All industries
# 6  2021                     Level 1                99999       All industries
# 7  2021                     Level 1                99999       All industries
# 8  2021                     Level 1                99999       All industries
# 9  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# ...

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
grp = df.groupby("Units")

# %%
grp.get_group("Percentage")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 26     2021                     Level 1                99999
# 27     2021                     Level 1                99999
# 28     2021                     Level 1                99999
# 29     2021                     Level 1                99999
# 30     2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 26                 All industries  Percentage           H36
# 27                 All industries  Percentage           H37
# ...

# %%
df.count()
# Out:
# Year                           41715
# Industry_aggregation_NZSIOC    41715
# Industry_code_NZSIOC           41715
# Industry_name_NZSIOC           41715
# Units                          41715
# Variable_code                  41715
# Variable_name                  41715
# Variable_category              41715
# Value                          41715
# Industry_code_ANZSIC06         41715
# dtype: int64

# %%
grp1 = grp.get_group("Dollars (millions)")

# %%
grp1["Industry_aggregation_NZSIOC"].value_counts()
# Out:
# Level 4    17973
# Level 3    10836
# Level 1     3987
# Name: Industry_aggregation_NZSIOC, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot([df["Year"]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fda816922b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fda81692910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fda81679e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fda816a4070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fda816a4400>],
#  'means': []}
